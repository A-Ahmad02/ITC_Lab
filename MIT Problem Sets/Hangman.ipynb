# %% [markdown]
# # Hangman

# %%
# Problem Set 2, hangman.py
# Name: 
# Collaborators:
# Time spent:

# Hangman Game
# -----------------------------------
# Helper code
# You don't need to understand this helper code,
# but you will have to know how to use the functions
# (so be sure to read the docstrings!)
import random
import string

WORDLIST_FILENAME = "words.txt"


def load_words():
    """
    Returns a list of valid words. Words are strings of lowercase letters.
    
    Depending on the size of the word list, this function may
    take a while to finish.
    """
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist



def choose_word(wordlist):
    """
    wordlist (list): list of words (strings)
    
    Returns a word from wordlist at random
    """
    return random.choice(wordlist)

# end of helper code

# -----------------------------------

# Load the list of words into the variable wordlist
# so that it can be accessed from anywhere in the program
wordlist = load_words()


def is_word_guessed(secret_word, letters_guessed):
    '''
    secret_word: string, the word the user is guessing; assumes all letters are
      lowercase
    letters_guessed: list (of letters), which letters have been guessed so far;
      assumes that all letters are lowercase
    returns: boolean, True if all the letters of secret_word are in letters_guessed;
      False otherwise
    '''
    for i in secret_word:
        if i not in letters_guessed:
            return False
        
    return True



def get_guessed_word(secret_word, letters_guessed):
    '''
    secret_word: string, the word the user is guessing
    letters_guessed: list (of letters), which letters have been guessed so far
    returns: string, comprised of letters, underscores (_), and spaces that represents
      which letters in secret_word have been guessed so far.
    '''
    guessed_word = ''
    for i in secret_word:
        if i not in letters_guessed:
            guessed_word += '_ '
        else:
            guessed_word += str(i)
    return guessed_word



def get_available_letters(letters_guessed):
    '''
    letters_guessed: list (of letters), which letters have been guessed so far
    returns: string (of letters), comprised of letters that represents which letters have not
      yet been guessed.
    '''
    available_letters = ''
    import string 
    for i in string.ascii_lowercase:
        if i not in letters_guessed:
            available_letters += str(i)
    return available_letters
    
    

def hangman(secret_word):
    '''
    secret_word: string, the secret word to guess.
    
    Starts up an interactive game of Hangman.
    
    * At the start of the game, let the user know how many 
      letters the secret_word contains and how many guesses s/he starts with.
      
    * The user should start with 6 guesses

    * Before each round, you should display to the user how many guesses
      s/he has left and the letters that the user has not yet guessed.
    
    * Ask the user to supply one guess per round. Remember to make
      sure that the user puts in a letter!
    
    * The user should receive feedback immediately after each guess 
      about whether their guess appears in the computer's word.

    * After each guess, you should display to the user the 
      partially guessed word so far.
    
    Follows the other limitations detailed in the problem write-up.
    '''
    letters_guessed = []
    print("Welcome to the game Hangman!")
    print("I am thinking of a word that is", len(secret_word), "letters long.")
    
    for i in range(6,0,-1):
        print("-------------")
        print("You have", i , "guesses left.")
        print("Available letters: ", get_available_letters(letters_guessed))
        a = input("Please guess a letter: ")
        letters_guessed.append(a)
        if is_word_guessed(a):
            print("Good guess: ", get_guessed_word(secret_word, letters_guessed))
        else:
            print("Oops! That letter is not in my word: ", get_guessed_word(secret_word, letters_guessed))


# When you've completed your hangman function, scroll down to the bottom
# of the file and uncomment the first two lines to test
#(hint: you might want to pick your own
# secret_word while you're doing your own testing)


# -----------------------------------



def match_with_gaps(my_word, other_word):
    '''
    my_word: string with _ characters, current guess of secret word
    other_word: string, regular English word
    returns: boolean, True if all the actual letters of my_word match the 
        corresponding letters of other_word, or the letter is the special symbol
        _ , and my_word and other_word are of the same length;
        False otherwise: 
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"
    pass



def show_possible_matches(my_word):
    '''
    my_word: string with _ characters, current guess of secret word
    returns: nothing, but should print out every word in wordlist that matches my_word
             Keep in mind that in hangman when a letter is guessed, all the positions
             at which that letter occurs in the secret word are revealed.
             Therefore, the hidden letter(_ ) cannot be one of the letters in the word
             that has already been revealed.

    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"
    pass



def hangman_with_hints(secret_word):
    '''
    secret_word: string, the secret word to guess.
    
    Starts up an interactive game of Hangman.
    
    * At the start of the game, let the user know how many 
      letters the secret_word contains and how many guesses s/he starts with.
      
    * The user should start with 6 guesses
    
    * Before each round, you should display to the user how many guesses
      s/he has left and the letters that the user has not yet guessed.
    
    * Ask the user to supply one guess per round. Make sure to check that the user guesses a letter
      
    * The user should receive feedback immediately after each guess 
      about whether their guess appears in the computer's word.

    * After each guess, you should display to the user the 
      partially guessed word so far.
      
    * If the guess is the symbol *, print out all words in wordlist that
      matches the current guessed word. 
    
    Follows the other limitations detailed in the problem write-up.
    '''
    # FILL IN YOUR CODE HERE AND DELETE "pass"
    pass



# When you've completed your hangman_with_hint function, comment the two similar
# lines above that were used to run the hangman function, and then uncomment
# these two lines and run this file to test!
# Hint: You might want to pick your own secret_word while you're testing.


if __name__ == "__main__":
    # pass

    # To test part 2, comment out the pass line above and
    # uncomment the following two lines.
    
    secret_word = choose_word(wordlist)
    hangman(secret_word)

###############
    
    # To test part 3 re-comment out the above lines and 
    # uncomment the following two lines. 
    
    #secret_word = choose_word(wordlist)
    #hangman_with_hints(secret_word)
# Out:
# Loading word list from file...
#    55900 words loaded.
# Welcome to the game Hangman!
# I am thinking of a word that is 8 letters long.
# -------------
# You have 6 guesses left.
# Available letters:  abcdefghijklmnopqrstuvwxyz
# Please guess a letter: s
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9676/3759216963.py in <module>
#     226
#     227     secret_word = choose_word(wordlist)
# --> 228     hangman(secret_word)
#     229
#     230 ###############
#
# ~\AppData\Local\Temp/ipykernel_9676/3759216963.py in hangman(secret_word)
#     136         a = input("Please guess a letter: ")
#     137         letters_guessed.append(a)
# --> 138         if is_word_guessed(a):
#     139             print("Good guess: ", get_guessed_word(secret_word, letters_guessed))
#     140         else:
#
# TypeError: is_word_guessed() missing 1 required positional argument: 'letters_guessed'

# %%
def is_word_guessed(secret_word, letters_guessed):
    for i in secret_word:
        if i not in letters_guessed:
            return False
        
    return True

secret_word = 'it'
letters_guessed = ['i','p','l','t']
print(is_word_guessed(secret_word, letters_guessed))
# Out:
# True

# %%
def get_guessed_word(secret_word, letters_guessed):
    guessed_word = ''
    for i in secret_word:
        if i not in letters_guessed:
            guessed_word += '_ '
        else:
            guessed_word += str(i)
    return guessed_word

secret_word = 'apple'  
letters_guessed = ['e', 'i', 'k', 'p', 'r', 's'] 
print(get_guessed_word(secret_word, letters_guessed))
# Out:
# _ pp_ e

# %%
def get_available_letters(letters_guessed):
    available_letters = ''
    import string 
    for i in string.ascii_lowercase:
        if i not in letters_guessed:
            available_letters += str(i)
    return available_letters

letters_guessed = ['e', 'i', 'k', 'p', 'r', 's'] 
print(get_available_letters(letters_guessed))
# Out:
# abcdfghjlmnoqtuvwxyz

# %%
def choose_word(wordlist):
    return random.choice(wordlist)

def hangman(secret_word):
    letters_guessed = []
    u = 0
    w = 3
    g = 6
    print("Welcome to the game Hangman!")
    print("I am thinking of a word that is", len(secret_word), "letters long.")
    print("You have", w, "warnings left")
    print("-------------")
    
    while g > 0:
        print("You have", g , "guesses left.")
        print("Available letters: ", get_available_letters(letters_guessed))
        a = str.lower(input("Please guess a letter: "))
        
        if not str.isalpha(a):
            if w == 0:
                g -= 1
            else:
                w -= 1
            print("Oops! That is not a valid letter. You have", w, "warnings left:", get_guessed_word(secret_word, letters_guessed))
        elif a in letters_guessed:
            if w == 0:
                g -= 1
            else:
                w -= 1
            print("Oops! You've already guessed that letter. You have", w, "warnings left:", get_guessed_word(secret_word, letters_guessed))
        elif a in secret_word:
            u += 1
            letters_guessed.append(a)
            print("Good guess: ", get_guessed_word(secret_word, letters_guessed))
        else:
            letters_guessed.append(a)
            print("Oops! That letter is not in my word: ", get_guessed_word(secret_word, letters_guessed))
            g -= 1
        print("-------------")
        
        if is_word_guessed(secret_word, letters_guessed):
            break
            
    if is_word_guessed(secret_word, letters_guessed):
        print("Congratulations, you won!")
        print("Your total score for this game is:", g*u)
    else:
        print("Sorry, you ran out of guesses. The word was "+str(secret_word)+".")  
        
secret_word = choose_word(wordlist)
hangman(secret_word)
# Out:
# Welcome to the game Hangman!
# I am thinking of a word that is 8 letters long.
# You have 3 warnings left
# -------------
# You have 6 guesses left.
# Available letters:  abcdefghijklmnopqrstuvwxyz
# Please guess a letter: s
# Good guess:  _ _ _ _ _ _ _ s
# -------------
# You have 6 guesses left.
# Available letters:  abcdefghijklmnopqrtuvwxyz
# Please guess a letter: a
# Good guess:  _ _ _ _ _ a_ s
# -------------
# You have 6 guesses left.
# Available letters:  bcdefghijklmnopqrtuvwxyz
# Please guess a letter: e
# Good guess:  _ e_ _ ea_ s
# -------------
# You have 6 guesses left.
# Available letters:  bcdfghijklmnopqrtuvwxyz
# Please guess a letter: l
# Oops! That letter is not in my word:  _ e_ _ ea_ s
# -------------
# You have 5 guesses left.
# Available letters:  bcdfghijkmnopqrtuvwxyz
# Please guess a letter: t
# Good guess:  _ et_ eats
# -------------
# You have 5 guesses left.
# Available letters:  bcdfghijkmnopqruvwxyz
# Please guess a letter: r
# Good guess:  retreats
# -------------
# Congratulations, you won!
# Your total score for this game is: 25

# %%
def match_with_gaps(my_word, other_word):
    my_word_gapless = ""
    
    for i in my_word:
        my_word_gapless += i.strip()
    
    if len(my_word_gapless) == len(other_word):
        for i in range(0,len(my_word_gapless),1):
            if my_word_gapless[i] == "_" and other_word[i] not in my_word_gapless:
                pass
            elif my_word_gapless[i] != other_word[i]:
                return False
        return True
    return False


match_with_gaps("a_ _ le", "apple")
# Out:
# True

# %%
def load_words():
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist

def show_possible_matches(my_word):
    word_list = load_words()
    possible_matches = ""
    for i in word_list:
        if match_with_gaps(my_word, i):
            possible_matches += (i+" ")
            
    if possible_matches == "":
        return "No matches found"
    else:
        return possible_matches



def hangman_with_hints(secret_word):
    letters_guessed = []
    u = 0
    w = 3
    g = 6
    print("Welcome to the game Hangman!")
    print("I am thinking of a word that is", len(secret_word), "letters long.")
    print("You have", w, "warnings left")
    print("-------------")
    
    while g > 0:
        print("You have", g , "guesses left.")
        print("Available letters: ", get_available_letters(letters_guessed))
        a = str.lower(input("Please guess a letter: "))
        if a == "*":
            print("Possible word matches are:")
            print(show_possible_matches(get_guessed_word(secret_word, letters_guessed)))
        
        elif not str.isalpha(a):
            if w == 0:
                g -= 1
            else:
                w -= 1
            print("Oops! That is not a valid letter. You have", w, "warnings left:", get_guessed_word(secret_word, letters_guessed))
        elif a in letters_guessed:
            if w == 0:
                g -= 1
            else:
                w -= 1
            print("Oops! You've already guessed that letter. You have", w, "warnings left:", get_guessed_word(secret_word, letters_guessed))
        elif a in secret_word:
            u += 1
            letters_guessed.append(a)
            print("Good guess: ", get_guessed_word(secret_word, letters_guessed))
        else:
            letters_guessed.append(a)
            print("Oops! That letter is not in my word: ", get_guessed_word(secret_word, letters_guessed))
            g -= 1
        print("-------------")
        
        if is_word_guessed(secret_word, letters_guessed):
            break
            
    if is_word_guessed(secret_word, letters_guessed):
        print("Congratulations, you won!")
        print("Your total score for this game is:", g*u)
    else:
        print("Sorry, you ran out of guesses. The word was "+str(secret_word)+".")  
        

secret_word = choose_word(wordlist) 
hangman_with_hints(secret_word)
# Out:
# Welcome to the game Hangman!
# I am thinking of a word that is 8 letters long.
# You have 3 warnings left
# -------------
# You have 6 guesses left.
# Available letters:  abcdefghijklmnopqrstuvwxyz
# Please guess a letter: d
# Oops! That letter is not in my word:  _ _ _ _ _ _ _ _
# -------------
# You have 5 guesses left.
# Available letters:  abcefghijklmnopqrstuvwxyz
# Please guess a letter: a
# Oops! That letter is not in my word:  _ _ _ _ _ _ _ _
# -------------
# You have 4 guesses left.
# Available letters:  bcefghijklmnopqrstuvwxyz
# Please guess a letter: o
# Good guess:  _ _ _ o_ _ _ _
# -------------
# You have 4 guesses left.
# Available letters:  bcefghijklmnpqrstuvwxyz
# Please guess a letter: *
# Possible word matches are:
# Loading word list from file...
#    55900 words loaded.
# abdomens abhorred abhorrer abnormal abrogate absolute absolved absolver absolves absorbed absorber accolade accompli accorded accosted accounts accouter acrobats acronyms acrostic adjoined adjourns admonish adroitly adsorbed advocacy advocate aerobics aeronaut aerostat afforded agnostic allocate allonyms allotted allowing alloying almoners ammonias ammoniac ammonite ammonium ampoules annotate announce annoying antonyms aphorism appoints apposing apposite arboreal argosies armoires armoring armories armorial arrogant arrogate arsonist ascorbic assonant assorted astonism astounds atrocity atrophic atropine attorney autobahn autocrat autoharp automats automate avionics baronies baroness baronets baronial barouche bayonets becoming bedouins befogged befouled begonias begotten beholder beholden belonged beloveds bemorned besotted besought betokens biconvex bifocals binomial bivouacs brioches cajoling cajolery calomels calories calorics camomile canoeing canoeist canonize canopied canopies caroling carolers carolina caroming carotene carotids caroused carouses carousal carousel cavorted cenobite cenotaph chlorals chlorate chloride chlorine chlorite chroming chromate chromite chromium cryogens cryonics culottes cynosure cytosine debonair decoying decocted decoding decoders decorate decorums deforest deformed deloused delouses democrat demolish demoniac demoting demounts denoting denounce deponent deported deportee deposing deposals deposits derogate desolate detonate detoured detoxify devolved devolves devoting devotees devoured devoutly dimorphs dinosaur disobeys disorder disowned divorced divorces divorcee eclogues ectoderm elbowing embodied embodies embolism embolden embossed embosses embowers emporium empowers encoding encoders encomium encoring endocarp endoderm endorsed endorser endorses endorsee endowing enfolded enforced enforcer enforces engorged engorges enjoined enjoying ennobled ennobles enrolled entombed escorted espoused espouses espousal estonian etiolate eulogies eulogize european europium exhorted exponent exported exporter exposing exposure expounds extolled extoller extorted fagoting famously favoring favorite felonies ferocity fluoride fluorine fluorite galoshes gasoline gatorade gavottes genocide genotype halogens hedonism hedonist hemostat heroisms heroines humoring humorist ideogram idiocies ignominy ignoring ignorant immobile immodest immolate immortal impolite imported importer imposing impotent impounds inboards incoming indolent informed informer informal innocent innovate insolent insomnia insomuch intoning invoiced invoices invoking involved involves jalopies jalousie japonica kerosene kiboshed kiboshes kilobits kilobyte kilogram kilowatt laboring laborers laborite lanolins layovers lemonier lemonade licorice limonite linoleum linotype madonnas mahogany majolica majoring majority manorial melodies memories memorial memoriam memorize mesoderm metonyms metonymy minority minotaur misogamy misogyny nepotism nicotine panorama parodied parodies paroling parolees parotids paroxysm peroxide piloting pinochle pivoting pleonasm pliocene priories priority prioress rebounds recoiled recorded recorder recounts recouped recourse recovers recovery redolent redouble redounds reforest reformed reformer reformat rehoused rehouses rejoiced rejoices rejoined reloaded relocate remodels remotest remotely remounts removing removers removals renounce renovate renowned reporter reported reposing reposals rerouted reroutes resolute resolves resolved resonant resonate resorted resounds resource retorted revoking revolted revolved revolver revolves reworded reworked rezoning rheostat ricochet riposted ripostes rumoring sabotage saboteur samovars samoyeds savoring savories scholars scrofula scrolled scrounge seconded secondly semolina shrouded simonize splotchy sprocket sprouted stroking strolled stroller stronger strongly strophes stropped suborder suborned synonyms synonymy synopses synopsis synoptic taconite theocrat theories theo ...
# -------------
# You have 4 guesses left.
# Available letters:  bcefghijklmnpqrstuvwxyz
# Please guess a letter: *
# Possible word matches are:
# Loading word list from file...
#    55900 words loaded.
# abdomens abhorred abhorrer abnormal abrogate absolute absolved absolver absolves absorbed absorber accolade accompli accorded accosted accounts accouter acrobats acronyms acrostic adjoined adjourns admonish adroitly adsorbed advocacy advocate aerobics aeronaut aerostat afforded agnostic allocate allonyms allotted allowing alloying almoners ammonias ammoniac ammonite ammonium ampoules annotate announce annoying antonyms aphorism appoints apposing apposite arboreal argosies armoires armoring armories armorial arrogant arrogate arsonist ascorbic assonant assorted astonism astounds atrocity atrophic atropine attorney autobahn autocrat autoharp automats automate avionics baronies baroness baronets baronial barouche bayonets becoming bedouins befogged befouled begonias begotten beholder beholden belonged beloveds bemorned besotted besought betokens biconvex bifocals binomial bivouacs brioches cajoling cajolery calomels calories calorics camomile canoeing canoeist canonize canopied canopies caroling carolers carolina caroming carotene carotids caroused carouses carousal carousel cavorted cenobite cenotaph chlorals chlorate chloride chlorine chlorite chroming chromate chromite chromium cryogens cryonics culottes cynosure cytosine debonair decoying decocted decoding decoders decorate decorums deforest deformed deloused delouses democrat demolish demoniac demoting demounts denoting denounce deponent deported deportee deposing deposals deposits derogate desolate detonate detoured detoxify devolved devolves devoting devotees devoured devoutly dimorphs dinosaur disobeys disorder disowned divorced divorces divorcee eclogues ectoderm elbowing embodied embodies embolism embolden embossed embosses embowers emporium empowers encoding encoders encomium encoring endocarp endoderm endorsed endorser endorses endorsee endowing enfolded enforced enforcer enforces engorged engorges enjoined enjoying ennobled ennobles enrolled entombed escorted espoused espouses espousal estonian etiolate eulogies eulogize european europium exhorted exponent exported exporter exposing exposure expounds extolled extoller extorted fagoting famously favoring favorite felonies ferocity fluoride fluorine fluorite galoshes gasoline gatorade gavottes genocide genotype halogens hedonism hedonist hemostat heroisms heroines humoring humorist ideogram idiocies ignominy ignoring ignorant immobile immodest immolate immortal impolite imported importer imposing impotent impounds inboards incoming indolent informed informer informal innocent innovate insolent insomnia insomuch intoning invoiced invoices invoking involved involves jalopies jalousie japonica kerosene kiboshed kiboshes kilobits kilobyte kilogram kilowatt laboring laborers laborite lanolins layovers lemonier lemonade licorice limonite linoleum linotype madonnas mahogany majolica majoring majority manorial melodies memories memorial memoriam memorize mesoderm metonyms metonymy minority minotaur misogamy misogyny nepotism nicotine panorama parodied parodies paroling parolees parotids paroxysm peroxide piloting pinochle pivoting pleonasm pliocene priories priority prioress rebounds recoiled recorded recorder recounts recouped recourse recovers recovery redolent redouble redounds reforest reformed reformer reformat rehoused rehouses rejoiced rejoices rejoined reloaded relocate remodels remotest remotely remounts removing removers removals renounce renovate renowned reporter reported reposing reposals rerouted reroutes resolute resolves resolved resonant resonate resorted resounds resource retorted revoking revolted revolved revolver revolves reworded reworked rezoning rheostat ricochet riposted ripostes rumoring sabotage saboteur samovars samoyeds savoring savories scholars scrofula scrolled scrounge seconded secondly semolina shrouded simonize splotchy sprocket sprouted stroking strolled stroller stronger strongly strophes stropped suborder suborned synonyms synonymy synopses synopsis synoptic taconite theocrat theories theo ...
# -------------
# You have 4 guesses left.
# Available letters:  bcefghijklmnpqrstuvwxyz
# Please guess a letter: e
# Good guess:  _ e_ o_ _ _ _
# -------------
# You have 4 guesses left.
# Available letters:  bcfghijklmnpqrstuvwxyz
# Please guess a letter: i
# Good guess:  _ e_ o_ i_ _
# -------------
# You have 4 guesses left.
# Available letters:  bcfghjklmnpqrstuvwxyz
# Please guess a letter: n
# Good guess:  _ e_ o_ in_
# -------------
# You have 4 guesses left.
# Available letters:  bcfghjklmpqrstuvwxyz
# Please guess a letter: g
# Good guess:  _ e_ o_ ing
# -------------
# You have 4 guesses left.
# Available letters:  bcfhjklmpqrstuvwxyz
# Please guess a letter: *
# Possible word matches are:
# Loading word list from file...
#    55900 words loaded.
# becoming decoying decoding demoting deposing devoting removing reposing revoking xeroxing
# -------------
# You have 4 guesses left.
# Available letters:  bcfhjklmpqrstuvwxyz
# Please guess a letter: r
# Good guess:  re_ o_ ing
# -------------
# You have 4 guesses left.
# Available letters:  bcfhjklmpqstuvwxyz
# Please guess a letter: v
# Good guess:  revo_ ing
# -------------
# You have 4 guesses left.
# Available letters:  bcfhjklmpqstuwxyz
# Please guess a letter: k
# Good guess:  revoking
# -------------
# Congratulations, you won!
# Your total score for this game is: 32

# %%
# Out:
# 'aabc'

# %%
import random
import string

WORDLIST_FILENAME = "words.txt"


def load_words():
    print("Loading word list from file...")
    # inFile: file
    inFile = open(WORDLIST_FILENAME, 'r')
    # line: string
    line = inFile.readline()
    # wordlist: list of strings
    wordlist = line.split()
    print("  ", len(wordlist), "words loaded.")
    return wordlist

def choose_word(wordlist):
    return random.choice(wordlist)

wordlist = load_words()


def is_word_guessed(secret_word, letters_guessed):
    for i in secret_word:
        if i not in letters_guessed:
            return False
    return True


def get_guessed_word(secret_word, letters_guessed):
    guessed_word = ''
    for i in secret_word:
        if i not in letters_guessed:
            guessed_word += '_ '
        else:
            guessed_word += str(i)
    return guessed_word

def get_available_letters(letters_guessed):
    available_letters = ''
    import string 
    for i in string.ascii_lowercase:
        if i not in letters_guessed:
            available_letters += str(i)
    return available_letters
    
    
def hangman(secret_word):
    letters_guessed = []
    u = 0
    w = 3
    g = 6
    print("Welcome to the game Hangman!")
    print("I am thinking of a word that is", len(secret_word), "letters long.")
    print("You have", w, "warnings left")
    print("-------------")
    
    while g > 0:
        print("You have", g , "guesses left.")
        print("Available letters: ", get_available_letters(letters_guessed))
        a = str.lower(input("Please guess a letter: "))
        
        if not str.isalpha(a):
            if w == 0:
                g -= 1
            else:
                w -= 1
            print("Oops! That is not a valid letter. You have", w, "warnings left:", get_guessed_word(secret_word, letters_guessed))
        elif a in letters_guessed:
            if w == 0:
                g -= 1
            else:
                w -= 1
            print("Oops! You've already guessed that letter. You have", w, "warnings left:", get_guessed_word(secret_word, letters_guessed))
        elif a in secret_word:
            u += 1
            letters_guessed.append(a)
            print("Good guess: ", get_guessed_word(secret_word, letters_guessed))
        else:
            letters_guessed.append(a)
            print("Oops! That letter is not in my word: ", get_guessed_word(secret_word, letters_guessed))
            g -= 1
        print("-------------")
        
        if is_word_guessed(secret_word, letters_guessed):
            break
            
    if is_word_guessed(secret_word, letters_guessed):
        print("Congratulations, you won!")
        print("Your total score for this game is:", g*u)
    else:
        print("Sorry, you ran out of guesses. The word was "+str(secret_word)+".")  
         
        
# -------------------------------------------------------------------------------------


def match_with_gaps(my_word, other_word):
    my_word_gapless = ""
    
    for i in my_word:
        my_word_gapless += i.strip()
    
    if len(my_word_gapless) == len(other_word):
        for i in range(0,len(my_word_gapless),1):
            if my_word_gapless[i] == "_" and other_word[i] not in my_word_gapless:
                pass
            elif my_word_gapless[i] != other_word[i]:
                return False
        return True
    return False


def show_possible_matches(my_word):
    word_list = load_words()
    possible_matches = ""
    for i in word_list:
        if match_with_gaps(my_word, i):
            possible_matches += (i+" ")
            
    if possible_matches == "":
        return "No matches found"
    else:
        return possible_matches



def hangman_with_hints(secret_word):
    letters_guessed = []
    u = 0
    w = 3
    g = 6
    print("Welcome to the game Hangman!")
    print("I am thinking of a word that is", len(secret_word), "letters long.")
    print("You have", w, "warnings left")
    print("-------------")
    
    while g > 0:
        print("You have", g , "guesses left.")
        print("Available letters: ", get_available_letters(letters_guessed))
        a = str.lower(input("Please guess a letter: "))
        if a == "*":
            print("Possible word matches are:")
            print(show_possible_matches(get_guessed_word(secret_word, letters_guessed)))
        
        elif not str.isalpha(a):
            if w == 0:
                g -= 1
            else:
                w -= 1
            print("Oops! That is not a valid letter. You have", w, "warnings left:", get_guessed_word(secret_word, letters_guessed))
        elif a in letters_guessed:
            if w == 0:
                g -= 1
            else:
                w -= 1
            print("Oops! You've already guessed that letter. You have", w, "warnings left:", get_guessed_word(secret_word, letters_guessed))
        elif a in secret_word:
            u += 1
            letters_guessed.append(a)
            print("Good guess: ", get_guessed_word(secret_word, letters_guessed))
        else:
            letters_guessed.append(a)
            print("Oops! That letter is not in my word: ", get_guessed_word(secret_word, letters_guessed))
            g -= 1
        print("-------------")
        
        if is_word_guessed(secret_word, letters_guessed):
            break
            
    if is_word_guessed(secret_word, letters_guessed):
        print("Congratulations, you won!")
        print("Your total score for this game is:", g*u)
    else:
        print("Sorry, you ran out of guesses. The word was "+str(secret_word)+".")  


if __name__ == "__main__":
    # pass

    # To test part 2, comment out the pass line above and
    # uncomment the following two lines.
    
#     secret_word = choose_word(wordlist)
#     hangman(secret_word)


    #secret_word = choose_word(wordlist)
    #hangman_with_hints(secret_word)
